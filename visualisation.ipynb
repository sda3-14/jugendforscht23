# %%
kcp500kb  = [3.078376534855553, 3.743029371581878  , 4.495217564594127 , 5.4076167277292   , 6.28661460019028 ]
kcp1000kb = [1.6652618521420215, 2.36754024435428  , 3.7324676570325455, 3.919579354904633 , 4.849579933488218]
kcp1500kb = [1.1973751704937354, 2.1216133037261318, 2.7448749116607623, 3.3854116787787123, 4.780426014469606]
kcp2000kb = [1.0602960872308131, 1.789007083718975 , 2.5663810364263377, 3.3264095769910025, 4.626668733916412]

tcp500kb  = [2.5720523944164095, 2.730020529964337 , 6.276360937505413 , 9.572999786062297 , 10.633389237212969]
tcp1000kb = [1.74011856826087  , 2.0803800467826075, 4.404808071199106 , 5.4551883656257965, 6.026569778142631 ]
tcp1500kb = [1.1973751704937354, 2.1216133037261318, 2.7448749116607623, 3.3854116787787123, 4.780426014469606 ]
tcp2000kb = [1.546259827016025 , 2.189287229067386 , 2.7643512628327858, 4.880383278986764 , 7.4501256380628265]

Unet500kb  = [48.701419895467026,30.80502545484584,61.86149379079219,58.99958136833167,73.17179749581139]
Unet1000kb = [13.551547623710563, 34.697287709467325, 51.88947144257592, 63.31204731891306, 69.13249152294301]
Unet1500kb = [9.128558349442411, 30.10484512397525, 46.97209273662873, 63.438377746804626, 82.12407738905777]
Unet2000kb = [13.002247381825901, 29.664730876046406, 43.609890667173985, 56.18241190835987, 74.32124791126161]
Unet3500kb = [10.126564155846342,32.08590629724714,44.27891626739852,55.130720189495186,65.7743471818489]
Unet7000kb = [8.347580752194462, 25.77357140759812, 45.19405039302604, 54.1977061285039, 67.33022754851771]

#unlimited
tcp     =   [0.8965327394021276, 3.630005444800811, 8.009763503629927, 24.59949055840642, 53.62472724442569, 79.5689927815297, 119.0514969799084, 132.98306687656188, 202.0700848236708]
kcp     =   [0.9173589905485232, 2.3639328763286684, 4.194440598953932, 5.740907913557327, 7.953063135335811, 10.723660666216453, 13.504645575501893, 15.949569746792728, 18.026939574999993]
unet    =   [2.57644960968999, 38.270882742269904, 62.61102576852639, 68.0205110458096, 87.38471444438748, 97.20657202374105, 104.20120675216748, 107.21693354141982, 118.34813995038178]
steamp2p=   [2.710216255763296, 5.777284938942393, 12.510442072776769, 19.383648000361642, 23.33429452337639, 27.01352878698326, 29.012450475838452, 34.898747000908415, 37.09003829839873]

# %%
from matplotlib import pyplot as plt

tcp      =   [0.8965327394021276, 3.630005444800811, 8.009763503629927, 24.59949055840642, 53.62472724442569, 79.5689927815297, 119.0514969799084, 132.98306687656188, 202.0700848236708]
kcp      =   [0.9173589905485232, 2.3639328763286684, 4.194440598953932, 5.740907913557327, 7.953063135335811, 10.723660666216453, 13.504645575501893, 15.949569746792728, 18.026939574999993]
unet     =   [2.57644960968999, 38.270882742269904, 62.61102576852639, 68.0205110458096, 87.38471444438748, 97.20657202374105, 104.20120675216748, 107.21693354141982, 118.34813995038178]
steamp2p =   [2.710216255763296, 5.777284938942393, 12.510442072776769, 19.383648000361642, 23.33429452337639, 27.01352878698326, 29.012450475838452, 34.898747000908415, 37.09003829839873]

#tcp = plt.plot([0,2.5,5,7.5,10,12.5,15,17.5,20],tcp)

kcp = plt.plot([0,2.5,5],[kcp[0],kcp[1],kcp[2]])

Unet500kbPLT  = plt.plot([0,1.25,2.5,3.75,5],Unet500kb)
Unet1000kbPLT = plt.plot([0,1.25,2.5,3.75,5],Unet1000kb)
Unet1500kbPLT = plt.plot([0,1.25,2.5,3.75,5],Unet1500kb)
Unet2000kbPLT = plt.plot([0,1.25,2.5,3.75,5],Unet2000kb)
Unet3500kbPLT = plt.plot([0,1.25,2.5,3.75,5],Unet3500kb)
Unet7000kbPLT = plt.plot([0,1.25,2.5,3.75,5],Unet7000kb)

#unet = plt.plot([0,2.5,5,7.5,10,12.5,15,17.5,20],unet)

#steamp2p = plt.plot([0,2.5,5,7.5,10,12.5,15,17.5,20],steamp2p)

plt.ylabel("latenz in ms")
plt.xlabel("loss in %")
labels = ["unlimited", "500kb","1mb","1.5mb", "2mb","3.5mb", "7mb"]
handles = [tcp,kcp,unet,steamp2p]
plt.legend(labels)
plt.margins(0)
plt.show()

# %%
steamp2p = plt.plot([0,2.5,5,7.5,10,12.5,15,17.5,20],steamp2p)

# %%
from matplotlib import pyplot as plt

tcp     =   [0.8965327394021276, 3.630005444800811, 8.009763503629927, 24.59949055840642, 53.62472724442569, 79.5689927815297, 119.0514969799084, 132.98306687656188, 202.0700848236708]
kcp     =   [0.9173589905485232, 2.3639328763286684, 4.194440598953932, 5.740907913557327, 7.953063135335811, 10.723660666216453, 13.504645575501893, 15.949569746792728, 18.026939574999993]
unet    =   [2.57644960968999, 38.270882742269904, 62.61102576852639, 68.0205110458096, 87.38471444438748, 97.20657202374105, 104.20120675216748, 107.21693354141982, 118.34813995038178]
steamp2p=   [2.710216255763296, 5.777284938942393, 12.510442072776769, 19.383648000361642, 23.33429452337639, 27.01352878698326, 29.012450475838452, 34.898747000908415, 37.09003829839873]

tcp = plt.plot([0,2.5,5,7.5,10,12.5,15,17.5,20],tcp)

kcp = plt.plot([0,2.5,5,7.5,10,12.5,15,17.5,20],kcp)

unet = plt.plot([0,2.5,5,7.5,10,12.5,15,17.5,20],unet)

steamp2p = plt.plot([0,2.5,5,7.5,10,12.5,15,17.5,20],steamp2p)

plt.ylabel("latenz in ms")
plt.xlabel("loss in %")
labels = ["TCP", "KCP", "UnrealEngine", "GameNetworkingSockets"]
handles = [tcp,kcp,unet,steamp2p]
plt.legend(labels)
plt.xcorr(0,0)
plt.show()
